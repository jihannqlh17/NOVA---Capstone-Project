# %%
import pandas as pd

dish = pd.read_csv("dish_nutrition_clean.csv")
ing = pd.read_csv("dish_ingredients_clean.csv")
meta = pd.read_csv("ingredients_metadata_clean.csv")

print(dish.shape)
print(ing.shape)
print(meta.shape)

print(dish.columns)
print(ing.columns)
print(meta.columns)
# Out:
# (4766, 11)
# (27223, 11)
# (555, 8)
# Index(['dish_id', 'calories', 'mass', 'fat', 'carb', 'protein',
#        'calorie_category', 'protein_density', 'fat_cal_pct', 'carb_cal_pct',
#        'protein_cal_pct'],
#       dtype='str')
# Index(['dish_id', 'ingr_id', 'ingr_name', 'grams', 'calories', 'fat', 'carb',
#        'protein', 'ingredient_count', 'ingr_cal_pct_of_dish',
#        'complexity_category'],
#       dtype='str')
# Index(['ingr_name', 'ingr_id', 'cal/g', 'fat(g)', 'carb(g)', 'protein(g)',
#        'calorie_density_category', 'macro_dominant'],
#       dtype='str')

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\THINKPAD\NOVA

# %%
print(dish.columns.tolist())
print(ing.columns.tolist())
print(meta.columns.tolist())
# Out:
# ['dish_id', 'calories', 'mass', 'fat', 'carb', 'protein', 'calorie_category', 'protein_density', 'fat_cal_pct', 'carb_cal_pct', 'protein_cal_pct']
# ['dish_id', 'ingr_id', 'ingr_name', 'grams', 'calories', 'fat', 'carb', 'protein', 'ingredient_count', 'ingr_cal_pct_of_dish', 'complexity_category']
# ['ingr_name', 'ingr_id', 'cal/g', 'fat(g)', 'carb(g)', 'protein(g)', 'calorie_density_category', 'macro_dominant']
